# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Data Load & Process

# %%
df = pd.read_csv(f"data/1-raw/lending-club-2007-2020Q3/Loan_status_2007-2020Q3-100ksample.csv")

df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0         id  loan_amnt  funded_amnt  \
# 0       1746494       25450  167338079     4000.0       4000.0
# 1       2370717       81861   71016917    24000.0      24000.0
# 2       2264870      397109   39589826     5000.0       5000.0
# 3        595422       15492  134798709    24000.0      24000.0
# 4        562657       90591  127097355    14000.0      14000.0
#
#    funded_amnt_inv        term int_rate  installment grade sub_grade  \
# 0           4000.0   36 months   13.08%       134.93     B        B5
# 1          24000.0   60 months    9.16%       500.07     B        B2
# 2           5000.0   36 months   10.49%       162.49     B        B3
# 3          24000.0   60 months   11.05%       522.42     B        B4
# 4          14000.0   60 months   13.59%       322.79     C        C2
#
#         emp_title emp_length home_ownership  annual_inc verification_status  \
# 0         cashier  10+ years       MORTGAGE     48000.0     Source Verified
# 1             ABM    6 years           RENT     57000.0     Source Verified
# 2          driver  10+ years       MORTGAGE     55000.0        Not Verified
# 3             NaN        NaN       MORTGAGE     43500.0        Not Verified
# 4  Shipping Clerk  10+ years       MORTGAGE     48000.0     Source Verified
#
#     issue_d loan_status pymnt_plan  \
# 0  Mar-2020     Current          n
# 1  Feb-2016     Current          n
# 2  Jan-2015  Fully Paid          n
# 3  Jun-2018     Current          n
# 4  Jan-2018  Fully Paid          n
#
#                                                  url             purpose  \
# 0  https://lendingclub.com/browse/loanDetail.acti...    home_improvement
# 1  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 2  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 3  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 4  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
#
#                      title zip_code addr_state    dti  delinq_2yrs  \
# 0         Home improvement    115xx         NY  20.25          1.0
# 1  Credit card refinancing    708xx         LA  25.33          0.0
# 2  Credit card refinancing    347xx         FL   7.22          0.0
# 3       Debt consolidation    443xx         OH  24.55          0.0
# 4       Debt consolidation    681xx         NE  24.30          0.0
#
#   earliest_cr_line  fico_range_low  fico_range_high  inq_last_6mths  \
# 0         Dec-2004           665.0            669.0             0.0
# 1         Jan-2004           680.0            684.0             0.0
# 2         Apr-2010           665.0            669.0             0.0
# 3         Oct-2005           750.0            754.0             0.0
# 4         Apr-2008           735.0            739.0             1.0
#
#    mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 0                    19.0                   110.0       4.0      1.0
# 1                     NaN                     NaN      10.0      0.0
# 2                     NaN                    61.0       7.0      1.0
# 3                     NaN                     NaN      15.0      0.0
# 4                     NaN                     NaN      16.0      0.0
#
#    revol_bal revol_util  total_acc initial_list_status  out_prncp  \
# 0     1988.0      82.8%       12.0                   w    3816.34
# 1    22697.0      64.5%       24.0                   w    4333.29
# 2     6001.0      52.6%        9.0                   f       0.00
# 3     6573.0      12.1%       23.0                   w   16317.69
# 4    11894.0      27.1%       23.0                   w       0.00
#
#    out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0        3816.34    266.950000           266.95           183.66
# 1        4333.29  25496.160000         25496.16         19666.71
# 2           0.00   5846.672836          5846.67          5000.00
# 3       16317.69  12000.930000         12000.93          7682.31
# 4           0.00  16605.680000         16605.68         14000.00
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0          83.29                 0.0         0.0                      0.0
# 1        5829.45                 0.0         0.0                      0.0
# 2         846.67                 0.0         0.0                      0.0
# 3        4318.62                 0.0         0.0                      0.0
# 4        2605.68                 0.0         0.0                      0.0
#
#   last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 
0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0           0.0                 0.0                 0.0            75.0
# 1           0.0                 0.0                 1.0            95.8
# 2           0.0                 0.0                 1.0           100.0
# 3           0.0                 0.0                 2.0            95.7
# 4           0.0                 0.0                 4.0           100.0
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0               NaN                   1.0        0.0         395328.0
# 1              60.0                   0.0        0.0          88154.0
# 2              33.3                   0.0        1.0         171118.0
# 3               0.0                   0.0        0.0         202606.0
# 4               0.0                   0.0        0.0         152081.0
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0            11948.0             0.0                     17928.0
# 1            61815.0         13000.0                     52954.0
# 2            13124.0         10000.0                      7526.0
# 3            18520.0         49000.0                     20000.0
# 4            34847.0         28800.0                     38181.0
#
#    revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 0              NaN                     NaN                      NaN
# 1              NaN                     NaN                      NaN
# 2              NaN                     NaN                      NaN
# 3              NaN                     NaN                      NaN
# 4              NaN                     NaN                      NaN
#
#   sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 0                      NaN                     NaN               NaN
# 1                      NaN                     NaN               NaN
# 2                      NaN                     NaN               NaN
# 3                      NaN                     NaN               NaN
# 4                      NaN                     NaN               NaN
#
#    sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 0               NaN                 NaN                  NaN
# 1               NaN                 NaN                  NaN
# 2               NaN                 NaN                  NaN
# 3               NaN                 NaN                  NaN
# 4               NaN                 NaN                  NaN
#
#    sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#    sec_app_collections_12_mths_ex_med hardship_flag hardship_type  \
# 0                                 NaN             N           NaN
# 1                                 NaN             N           NaN
# 2                                 NaN             N           NaN
# 3                                 NaN             N           NaN
# 4                                 NaN             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0             NaN             NaN            NaN              NaN
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
# 3             NaN             NaN            NaN              NaN
# 4             NaN             NaN            NaN              NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0                 NaN               NaN                     NaN
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              NaN           NaN                  NaN
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
# 3              NaN           NaN                  NaN
# 4              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount debt_settlement_flag
# 0                           NaN                    N
# 1                           NaN                    N
# 2                           NaN                    N
# 3                           NaN                    N
# 4                           NaN                    N

# %%
list_to_drop = ['Unnamed: 0.1', 'Unnamed: 0']
df_dropped = df.drop(list_to_drop, axis = 1)

# %%
# df_dropped.shape,
desc_df = df_dropped.describe()

desc_df.loc['std',:].sort_values()
# Out:
# policy_code                                   0.000000e+00
# num_tl_120dpd_2m                              2.157487e-02
# num_tl_30dpd                                  5.107280e-02
# acc_now_delinq                                6.346707e-02
# chargeoff_within_12_mths                      1.022904e-01
# collections_12_mths_ex_med                    1.442911e-01
# sec_app_collections_12_mths_ex_med            3.359442e-01
# sec_app_chargeoff_within_12_mths              3.485665e-01
# pub_rec_bankruptcies                          3.543980e-01
# tax_liens                                     3.657402e-01
# num_tl_90g_dpd_24m                            4.565536e-01
# pub_rec                                       5.507502e-01
# deferral_term                                 5.628247e-01
# hardship_length                               5.628247e-01
# delinq_2yrs                                   8.235203e-01
# inq_last_6mths                                8.627038e-01
# open_il_12m                                   9.413304e-01
# sec_app_inq_last_6mths                        9.850406e-01
# open_acc_6m                                   1.132691e+00
# num_accts_ever_120_pd                         1.331150e+00
# open_rv_12m                                   1.491800e+00
# inq_fi                                        1.496386e+00
# open_il_24m                                   1.595079e+00
# sec_app_mort_acc                              1.757735e+00
# num_tl_op_past_12m                            1.844204e+00
# mort_acc                                      1.870317e+00
# inq_last_12m                                  2.349284e+00
# num_actv_bc_tl                                2.380707e+00
# open_rv_24m                                   2.560293e+00
# total_cu_tl                                   2.719705e+00
# open_act_il                                   3.034160e+00
# num_bc_sats                                   3.116711e+00
# acc_open_past_24mths                          3.173066e+00
# num_rev_tl_bal_gt_0                           3.339014e+00
# sec_app_open_act_il                           3.360015e+00
# num_actv_rev_tl                               3.411094e+00
# num_bc_tl                                     4.694096e+00
# num_op_rev_tl                                 4.786651e+00
# open_acc                                      5.754573e+00
# num_sats                                      5.759304e+00
# mths_since_recent_inq                         5.971433e+00
# hardship_dpd                                  6.048766e+00
# sec_app_open_acc                              6.906913e+00
# num_il_tl                                     7.432067e+00
# dti_joint                                     7.930092e+00
# num_rev_accts                                 8.035361e+00
# sec_app_num_rev_accts                         8.367637e+00
# pct_tl_nvr_dlq                                8.926635e+00
# mo_sin_rcnt_tl                                9.267053e+00
# total_acc                                     1.205559e+01
# total_rec_late_fee                            1.341665e+01
# dti                                           1.727805e+01
# mo_sin_rcnt_rev_tl_op                         1.798912e+01
# all_util                                      2.080431e+01
# mths_since_last_major_derog                   2.162455e+01
# mths_since_last_delinq                        2.191537e+01
# mths_since_recent_revol_delinq                2.220807e+01
# mths_since_recent_bc_dlq                      2.255151e+01
# il_util                                       2.348203e+01
# mths_since_rcnt_il                            2.524276e+01
# sec_app_revol_util                            2.579140e+01
# mths_since_last_record                        2.656024e+01
# bc_util                                       2.884206e+01
# mths_since_recent_bc                          3.251495e+01
# fico_range_low                                3.380100e+01
# fico_range_high                               3.380202e+01
# percent_bc_gt_75                              3.606889e+01
# sec_app_fico_range_low                        4.486209e+01
# sec_app_fico_range_high                       4.486265e+01
# mo_sin_old_il_acct                            5.448101e+01
# last_fico_range_high                          7.490340e+01
# mo_sin_old_rev_tl_op                          9.840282e+01
# last_fico_range_low                           1.152054e+02
# collection_recovery_fee                       1.435867e+02
# hardship_amount                               2.485848e+02
# installment                                   2.730226e+02
# orig_projected_additional_accrued_interest    4.771880e+02
# delinq_amnt                                   6.949301e+02
# recoveries                                    8.082897e+02
# tot_coll_amt                                  1.680478e+03
# hardship_last_payment_amount                  2.103127e+03
# total_rec_int                                 2.766019e+03
# max_bal_bc                                    5.513921e+03
# last_pymnt_amnt                               6.189948e+03
# out_prncp_inv                                 7.464709e+03
# out_prncp                                     7.465243e+03
# total_rec_prncp                               8.669888e+03
# hardship_payoff_balance_amount                9.246628e+03
# funded_amnt                                   9.467415e+03
# loan_amnt                                     9.468190e+03
# funded_amnt_inv                               9.470919e+03
# total_pymnt_inv                               1.033363e+04
# total_pymnt                                   1.033736e+04
# avg_cur_bal                                   1.669322e+04
# bc_open_to_buy                                1.809939e+04
# revol_bal                                     2.239829e+04
# total_bc_limit                                2.448759e+04
# revol_bal_joint                               3.185786e+04
# total_rev_hi_lim                              3.582365e+04
# total_bal_il                                  4.607293e+04
# total_il_high_credit_limit                    4.693562e+04
# total_bal_ex_mort                             5.172936e+04
# annual_inc_joint                              6.799755e+04
# annual_inc                                    8.722434e+04
# tot_cur_bal                                   1.644569e+05
# tot_hi_cred_lim                               1.840932e+05
# id                                            5.114736e+07
# Name: std, dtype: float64

# %% [markdown]
# STD from desc object
#
# total_rec_prncp                               8.669888e+03,
# hardship_payoff_balance_amount                9.246628e+03,
# funded_amnt                                   9.467415e+03,
# loan_amnt                                     9.468190e+03,
# funded_amnt_inv                               9.470919e+03,
# total_pymnt_inv                               1.033363e+04,
# total_pymnt                                   1.033736e+04,
# avg_cur_bal                                   1.669322e+04,
# bc_open_to_buy                                1.809939e+04,
# revol_bal                                     2.239829e+04,
# revol_bal                                     2.239829e+04,
# total_bc_limit                                2.448759e+04,
# revol_bal_joint                               3.185786e+04,
# total_rev_hi_lim                              3.582365e+04,
# total_bal_il                                  4.607293e+04,
# total_il_high_credit_limit
#
# interesting that these have very large variances -> early feature contendors, depending on definition

# %%
df_dropped.nunique().sort_values()
# Out:
# policy_code                                        1
# pymnt_plan                                         1
# hardship_flag                                      2
# term                                               2
# debt_settlement_flag                               2
# application_type                                   2
# initial_list_status                                2
# num_tl_120dpd_2m                                   3
# verification_status_joint                          3
# verification_status                                3
# hardship_status                                    4
# num_tl_30dpd                                       4
# deferral_term                                      4
# hardship_length                                    4
# acc_now_delinq                                     5
# hardship_status_filled                             5
# chargeoff_within_12_mths                           6
# home_ownership                                     6
# hardship_type                                      6
# grade                                              7
# sec_app_collections_12_mths_ex_med                 7
# collections_12_mths_ex_med                         7
# sec_app_inq_last_6mths                             7
# pub_rec_bankruptcies                               8
# hardship_loan_status                               9
# loan_status                                       10
# sec_app_chargeoff_within_12_mths                  10
# open_il_12m                                       11
# inq_last_6mths                                    11
# emp_length                                        11
# sec_app_mort_acc                                  13
# open_acc_6m                                       13
# purpose                                           14
# tax_liens                                         17
# hardship_reason                                   17
# pub_rec                                           18
# num_tl_90g_dpd_24m                                18
# delinq_2yrs                                       19
# inq_fi                                            21
# open_rv_12m                                       21
# open_il_24m                                       22
# num_tl_op_past_12m                                23
# mths_since_recent_inq                             25
# mort_acc                                          25
# num_actv_bc_tl                                    30
# open_rv_24m                                       31
# num_accts_ever_120_pd                             31
# inq_last_12m                                      33
# sec_app_open_act_il                               33
# sub_grade                                         35
# hardship_dpd                                      36
# acc_open_past_24mths                              37
# num_bc_sats                                       38
# open_act_il                                       38
# total_cu_tl                                       40
# num_rev_tl_bal_gt_0                               40
# hardship_start_date                               41
# payment_plan_start_date                           41
# fico_range_high                                   42
# fico_range_low                                    42
# num_actv_rev_tl                                   42
# hardship_end_date                                 43
# sec_app_open_acc                                  50
# num_bc_tl                                         50
# addr_state                                        51
# num_op_rev_tl                                     55
# next_pymnt_d                                      58
# sec_app_fico_range_low                            60
# sec_app_fico_range_high                           60
# num_sats                                          61
# open_acc                                          61
# sec_app_num_rev_accts                             65
# last_fico_range_low                               71
# last_fico_range_high                              72
# num_il_tl                                         80
# num_rev_accts                                     80
# total_acc                                        103
# mths_since_last_record                           123
# mths_since_last_delinq                           128
# mths_since_recent_bc_dlq                         131
# mths_since_recent_revol_delinq                   134
# last_credit_pull_d                               137
# mths_since_last_major_derog                      139
# last_pymnt_d                                     147
# all_util                                         148
# mo_sin_rcnt_tl                                   152
# issue_d                                          159
# percent_bc_gt_75                                 160
# il_util                                          189
# mo_sin_rcnt_rev_tl_op                            207
# delinq_amnt                                      215
# mths_since_rcnt_il                               259
# mths_since_recent_bc                             341
# mo_sin_old_il_acct                               439
# pct_tl_nvr_dlq                                   462
# sec_app_earliest_cr_line                         506
# int_rate                                         584
# mo_sin_old_rev_tl_op                             662
# earliest_cr_line                                 667
# zip_code                                         878
# sec_app_revol_util                              1035
# revol_util                                      1088
# bc_util                                         1143
# loan_amnt                                       1479
# funded_amnt                                     1479
# hardship_amount                                 1594
# funded_amnt_inv                                 1793
# annual_inc_joint                                1837
# total_rec_late_fee                              2331
# total_bc_limit                                  2825
# dti_joint                                       2855
# title                                           3455
# tot_coll_amt                                    3656
# total_rev_hi_lim                                4187
# hardship_last_payment_amount                    4641
# dti                                             5334
# orig_projected_additional_accrued_interest      5521
# hardship_payoff_balance_amount                  5825
# revol_bal_joint                                 6440
# collection_recovery_fee                         8380
# recoveries                                      8498
# annual_inc                                      8852
# max_bal_bc                                     17470
# installment                                    28510
# out_prncp                                      32242
# out_prncp_inv                                  32333
# bc_open_to_buy                                 33138
# avg_cur_bal                                    34930
# revol_bal                                      37407
# emp_title                                      40094
# total_bal_il                                   44392
# total_rec_prncp                                44924
# total_il_high_credit_limit                     55050
# last_pymnt_amnt                                61178
# total_bal_ex_mort                              64944
# tot_hi_cred_lim                                76897
# tot_cur_bal                                    81168
# total_rec_int                                  86806
# total_pymnt_inv                                91836
# total_pymnt                                    93762
# url                                           100000
# id                                            100000
# dtype: int64

# %%
df_dropped.loan_status.value_counts()
# Out:
# Fully Paid                                             51189
# Current                                                35294
# Charged Off                                            12384
# Late (31-120 days)                                       535
# In Grace Period                                          329
# Late (16-30 days)                                         90
# Does not meet the credit policy. Status:Fully Paid        69
# Issued                                                    63
# Does not meet the credit policy. Status:Charged Off       33
# Default                                                   14
# Name: loan_status, dtype: int64

# %%
charged_off_loans = df_dropped[df_dropped.loan_status == "Charged Off"]

# Calculate average size of charged off loan
average_size_loan = charged_off_loans['loan_amnt'].mean()
formatted_average_size_loan = f"${average_size_loan:,.2f}"
print(f"""Average size of charged off loan:
         {
             formatted_average_size_loan
         }""")
# Out:
# Average size of charged off loan:
#          $15,784.87

# %%
# Quite a few nulls that need to be resolved.
df_dropped.isnull().sum()
# Out:
# id                                                0
# loan_amnt                                         0
# funded_amnt                                       0
# funded_amnt_inv                                   0
# term                                              0
# int_rate                                          0
# installment                                       0
# grade                                             0
# sub_grade                                         0
# emp_title                                      8954
# emp_length                                     6950
# home_ownership                                    0
# annual_inc                                        0
# verification_status                               0
# issue_d                                           0
# loan_status                                       0
# pymnt_plan                                        0
# url                                               0
# purpose                                           0
# title                                           780
# zip_code                                          0
# addr_state                                        0
# dti                                             102
# delinq_2yrs                                       0
# earliest_cr_line                                  0
# fico_range_low                                    0
# fico_range_high                                   0
# inq_last_6mths                                    0
# mths_since_last_delinq                        52814
# mths_since_last_record                        85370
# open_acc                                          0
# pub_rec                                           0
# revol_bal                                         0
# revol_util                                       81
# total_acc                                         0
# initial_list_status                               0
# out_prncp                                         0
# out_prncp_inv                                     0
# total_pymnt                                       0
# total_pymnt_inv                                   0
# total_rec_prncp                                   0
# total_rec_int                                     0
# total_rec_late_fee                                0
# recoveries                                        0
# collection_recovery_fee                           0
# last_pymnt_d                                    191
# last_pymnt_amnt                                   0
# next_pymnt_d                                  63573
# last_credit_pull_d                                2
# last_fico_range_high                              0
# last_fico_range_low                               0
# collections_12_mths_ex_med                        6
# mths_since_last_major_derog                   75398
# policy_code                                       0
# application_type                                  0
# annual_inc_joint                              92834
# dti_joint                                     92834
# verification_status_joint                     93369
# acc_now_delinq                                    0
# tot_coll_amt                                   2438
# tot_cur_bal                                    2438
# open_acc_6m                                   29644
# open_act_il                                   29644
# open_il_12m                                   29644
# open_il_24m                                   29644
# mths_since_rcnt_il                            31773
# total_bal_il                                  29644
# il_util                                       39685
# open_rv_12m                                   29644
# open_rv_24m                                   29644
# max_bal_bc                                    29644
# all_util                                      29657
# total_rev_hi_lim                               2438
# inq_fi                                        29644
# total_cu_tl                                   29644
# inq_last_12m                                  29644
# acc_open_past_24mths                           1778
# avg_cur_bal                                    2440
# bc_open_to_buy                                 2848
# bc_util                                        2899
# chargeoff_within_12_mths                          6
# delinq_amnt                                       0
# mo_sin_old_il_acct                             5373
# mo_sin_old_rev_tl_op                           2438
# mo_sin_rcnt_rev_tl_op                          2438
# mo_sin_rcnt_tl                                 2438
# mort_acc                                       1778
# mths_since_recent_bc                           2788
# mths_since_recent_bc_dlq                      78057
# mths_since_recent_inq                         12810
# mths_since_recent_revol_delinq                68342
# num_accts_ever_120_pd                          2438
# num_actv_bc_tl                                 2438
# num_actv_rev_tl                                2438
# num_bc_sats                                    2051
# num_bc_tl                                      2438
# num_il_tl                                      2438
# num_op_rev_tl                                  2438
# num_rev_accts                                  2438
# num_rev_tl_bal_gt_0                            2438
# num_sats                                       2051
# num_tl_120dpd_2m                               5512
# num_tl_30dpd                                   2438
# num_tl_90g_dpd_24m                             2438
# num_tl_op_past_12m                             2438
# pct_tl_nvr_dlq                                 2442
# percent_bc_gt_75                               2867
# pub_rec_bankruptcies                             45
# tax_liens                                         5
# tot_hi_cred_lim                                2438
# total_bal_ex_mort                              1778
# total_bc_limit                                 1778
# total_il_high_credit_limit                     2438
# revol_bal_joint                               93261
# sec_app_fico_range_low                        93260
# sec_app_fico_range_high                       93260
# sec_app_earliest_cr_line                      93260
# sec_app_inq_last_6mths                        93260
# sec_app_mort_acc                              93260
# sec_app_open_acc                              93260
# sec_app_revol_util                            93387
# sec_app_open_act_il                           93260
# sec_app_num_rev_accts                         93260
# sec_app_chargeoff_within_12_mths              93260
# sec_app_collections_12_mths_ex_med            93260
# hardship_flag                                  1327
# hardship_type                                 95105
# hardship_reason                               95105
# hardship_status                               95105
# deferral_term                                 95105
# hardship_amount                               93778
# hardship_start_date                           95105
# hardship_end_date                             95105
# payment_plan_start_date                       95105
# hardship_length                               95105
# hardship_dpd                                  95105
# hardship_loan_status                          95116
# orig_projected_additional_accrued_interest    93873
# hardship_payoff_balance_amount                93778
# hardship_last_payment_amount                  93778
# debt_settlement_flag                              0
# dtype: int64

# %%
# Create hardship flag based on information provided by data SMEs in the business
df_dropped['hardship_status_filled'] = df_dropped['hardship_status'].fillna("NO_HARDSHIP")
print(f"Nulls after filling: {df_dropped['hardship_status_filled'].isnull().sum()}")
# Out:
# Nulls after filling: 0

# %%
# Imputation: Filling missing values with the mean for numerical columns
df_dropped['num_accts_ever_120_pd'].fillna(df_dropped['num_accts_ever_120_pd'].mean(), inplace=True)
print(f"Nulls after filling: {df_dropped['num_accts_ever_120_pd'].isnull().sum()}")
# Out:
# Nulls after filling: 0

# %%
# Checking for duplicate rows
duplicates = df_dropped.duplicated().sum()
duplicates
# Out:
# 0

# %%
# Removing duplicate rows
df_deduped = df_dropped.drop_duplicates(inplace=True)

try:
    df_deduped.shape # Note: it will fail if empty (i.e. no duplicates)
except:
    print("No duplicates")
# Out:
# No duplicates

# %% [markdown]
# ### Outlier Detection

# %%
from scipy import stats
import numpy as np
import seaborn as sns


threshold = 3

for i in range(200, 301, 25):
    thresh = threshold/100
    print(f"Threshold == {thresh}, {df_dropped[np.abs(z_scores)>thresh].shape[0]} outliers ")
    
z_scores = np.abs(stats.zscore(df_dropped.select_dtypes(include=[np.number])))

gt_thresh = z_scores > threshold
outlier_volume = pd.DataFrame(gt_thresh.sum(), columns=["num_outliers"])
outlier_volume.sort_values(by = "num_outliers"
                          , ascending= False)
# Out:
# Threshold == 0.03, 99389 outliers
# Threshold == 0.03, 99389 outliers
# Threshold == 0.03, 99389 outliers
# Threshold == 0.03, 99389 outliers
# Threshold == 0.03, 99389 outliers
#                                             num_outliers
# last_pymnt_amnt                                     2707
# out_prncp                                           2704
# out_prncp_inv                                       2703
# delinq_2yrs                                         2346
# num_accts_ever_120_pd                               2204
# total_rec_int                                       2130
# recoveries                                          2068
# collection_recovery_fee                             1982
# pub_rec                                             1807
# last_fico_range_low                                 1790
# open_acc                                            1428
# revol_bal                                           1375
# total_pymnt                                         1189
# total_rec_late_fee                                  1186
# total_pymnt_inv                                     1184
# fico_range_high                                     1107
# fico_range_low                                      1107
# inq_last_6mths                                      1009
# total_acc                                            998
# total_rec_prncp                                      709
# installment                                          682
# annual_inc                                           567
# acc_now_delinq                                       323
# delinq_amnt                                           53
# last_fico_range_high                                   9
# num_tl_30dpd                                           0
# num_tl_90g_dpd_24m                                     0
# pub_rec_bankruptcies                                   0
# num_tl_op_past_12m                                     0
# tax_liens                                              0
# pct_tl_nvr_dlq                                         0
# percent_bc_gt_75                                       0
# num_tl_120dpd_2m                                       0
# num_bc_sats                                            0
# num_sats                                               0
# num_rev_tl_bal_gt_0                                    0
# num_rev_accts                                          0
# num_op_rev_tl                                          0
# num_actv_bc_tl                                         0
# total_bal_ex_mort                                      0
# num_actv_rev_tl                                        0
# num_il_tl                                              0
# num_bc_tl                                              0
# tot_hi_cred_lim                                        0
# id                                                     0
# total_bc_limit                                         0
# total_il_high_credit_limit                             0
# hardship_payoff_balance_amount                         0
# orig_projected_additional_accrued_interest             0
# hardship_dpd                                           0
# hardship_length                                        0
# hardship_amount                                        0
# deferral_term                                          0
# sec_app_collections_12_mths_ex_med                     0
# sec_app_chargeoff_within_12_mths                       0
# mths_since_recent_revol_delinq                         0
# sec_app_open_act_il                                    0
# sec_app_revol_util                                     0
# sec_app_open_acc                                       0
# sec_app_mort_acc                                       0
# sec_app_inq_last_6mths                                 0
# sec_app_fico_range_high                                0
# sec_app_fico_range_low                                 0
# revol_bal_joint                                        0
# sec_app_num_rev_accts                                  0
# avg_cur_bal                                            0
# mths_since_recent_inq                                  0
# il_util                                                0
# mths_since_rcnt_il                                     0
# open_il_24m                                            0
# open_il_12m                                            0
# open_act_il                                            0
# open_acc_6m                                            0
# tot_cur_bal                                            0
# tot_coll_amt                                           0
# dti_joint                                              0
# annual_inc_joint                                       0
# policy_code                                            0
# mths_since_last_major_derog                            0
# collections_12_mths_ex_med                             0
# mths_since_last_record                                 0
# mths_since_last_delinq                                 0
# dti                                                    0
# funded_amnt_inv                                        0
# funded_amnt                                            0
# total_bal_il                                           0
# open_rv_12m                                            0
# mths_since_recent_bc_dlq                               0
# open_rv_24m                                            0
# mths_since_recent_bc                                   0
# mort_acc                                               0
# mo_sin_rcnt_tl                                         0
# mo_sin_rcnt_rev_tl_op                                  0
# mo_sin_old_rev_tl_op                                   0
# mo_sin_old_il_acct                                     0
# chargeoff_within_12_mths                               0
# bc_util                                                0
# bc_open_to_buy                                         0
# loan_amnt                                              0
# acc_open_past_24mths                                   0
# inq_last_12m                                           0
# total_cu_tl                                            0
# inq_fi                                                 0
# total_rev_hi_lim                                       0
# all_util                                               0
# max_bal_bc                                             0
# hardship_last_payment_amount                           0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

field_to_plot = "last_pymnt_amnt"

# Plotting variable distribution with outliers
plt.figure(figsize=(12, 6))
sns.boxplot(x=df_dropped[field_to_plot])
plt.title(f"Distribution and outliers for {field_to_plot}")
plt.show()

# %% [markdown]
# Going with removal of outliers.
#
# firstly cons -> smaller sample size, risk of threshold mispecification.
#
# pros -> simpler and less noisy data, potential upside to model performance and improve accuracy.
#
# overall -> alot can go wrong with transforming and capping outliers making the modelling more complex. A
#             simpler framework that's successful is a good first step.

# %%
# Removing outliers
field_to_treat = "last_pymnt_amnt"

df_no_outliers = df_dropped[(z_scores[field_to_treat] < threshold)]
df_no_outliers.shape
# Out:
# (97293, 142)

# %%
# Plotting variable distribution with outliers
plt.figure(figsize=(12, 6))
sns.boxplot(x=df_dropped[field_to_plot])
plt.title(f"Distribution and outliers for {field_to_plot}")
plt.show()

# %%
df_dropped['url'].value_counts()[:5]
# Out:
# https://lendingclub.com/browse/loanDetail.action?loan_id=167338079    1
# https://lendingclub.com/browse/loanDetail.action?loan_id=693399       1
# https://lendingclub.com/browse/loanDetail.action?loan_id=119962746    1
# https://lendingclub.com/browse/loanDetail.action?loan_id=161374059    1
# https://lendingclub.com/browse/loanDetail.action?loan_id=74591293     1
# Name: url, dtype: int64

# %% [markdown]
# ### Feature Engineering

# %%
import re

def extract_loan_id_from_url(mystring):
    keyword = '='
    before_keyword, keyword, after_keyword = mystring.partition(keyword)
    return after_keyword

df_dropped['loan_id_extracted'] = df_dropped['url'].apply(extract_loan_id_from_url)
df_dropped[['id','url','loan_id_extracted']][:5]
# Out:
#           id                                                url  \
# 0  167338079  https://lendingclub.com/browse/loanDetail.acti...
# 1   71016917  https://lendingclub.com/browse/loanDetail.acti...
# 2   39589826  https://lendingclub.com/browse/loanDetail.acti...
# 3  134798709  https://lendingclub.com/browse/loanDetail.acti...
# 4  127097355  https://lendingclub.com/browse/loanDetail.acti...
#
#   loan_id_extracted
# 0         167338079
# 1          71016917
# 2          39589826
# 3         134798709
# 4         127097355

# %%
print("Number of unique titles:", df_dropped['emp_title'].value_counts().shape[0])
df_dropped['emp_title'].value_counts()[:10]
# Out:
# Number of unique titles: 40094
# Teacher             1709
# Manager             1547
# Owner                812
# Registered Nurse     691
# Driver               685
# RN                   651
# Supervisor           590
# Sales                515
# Office Manager       469
# Project Manager      441
# Name: emp_title, dtype: int64

# %%
# Cleaning text data
df_dropped['emp_title_clean'] = df_dropped['emp_title'].str.lower().str.strip()
df_dropped['emp_title_clean'].value_counts()[:10]

df_dropped['emp_title_manager'] = df_dropped['emp_title_clean'].str.contains("manager")
df_dropped['emp_title_manager'].value_counts()

selected_columns = df_dropped[["emp_title_manager", "emp_title_clean"]]
unique_combinations = selected_columns.drop_duplicates()
unique_combinations.head(10)
# Out:
#    emp_title_manager     emp_title_clean
# 0              False             cashier
# 1              False                 abm
# 2              False              driver
# 3                NaN                 NaN
# 4              False      shipping clerk
# 5              False                 csr
# 6              False             cdc lll
# 7              False       snr scientist
# 9              False          pharmacist
# 10             False  billing specialist

# %% [markdown]
# ### Joining to external data

# %%
ref_job_families = pd.read_csv(rf"data/1-raw/emp_title_mapping.csv")
ref_job_families.head()

print(f"Number of existing job families: {ref_job_families.Category.nunique()}")
# Out:
# Number of existing job families: 32

# %%
df_mapped = pd.merge(left = df_dropped
                     , right = ref_job_families
                     , left_on = "emp_title_clean"
                     , right_on= "Job Title"
                     , how = "left"
                    )

# %%
print(df_dropped.shape, df_mapped.shape)
# Out:
# (100000, 146) (102265, 148)

# %%
# Let's check if there are any duplicates in the reference file:
print(ref_job_families.shape)
print(ref_job_families.drop_duplicates().shape)
# Out:
# (91, 2)
# (89, 2)

# %%
# The problem can be seen by grouping the ref data by job title and category:
row_count = ref_job_families.groupby(["Category", "Job Title"]).size().reset_index(name='count')
row_count[row_count['count'] > 1]
# Out:
#       Category          Job Title  count
# 17   Education            teacher      2
# 35  Healthcare  medical assistant      2

# %%
ref_job_families[ref_job_families["Job Title"] == "medical assistant"]
# Out:
#             Job Title    Category
# 70  medical assistant  Healthcare
# 88  medical assistant  Healthcare

# %%
ref_job_families_deduped = ref_job_families.drop_duplicates()
print(ref_job_families.shape, ref_job_families_deduped.shape)
# Out:
# (91, 2) (89, 2)

# %%
df_mapped_deduped = pd.merge(left = df_dropped
                     , right = ref_job_families_deduped
                     , left_on = "emp_title_clean"
                     , right_on= "Job Title"
                     , how = "left"
                    )
print(df_dropped.shape, df_mapped_deduped.shape)
# Out:
# (100000, 146) (100000, 148)

# %%
# Extracting features from date column
df_dropped['issue_d'] = pd.to_datetime(df_dropped['issue_d'])

# %%
ts_loans = pd.DataFrame(df_dropped.groupby("issue_d").count()["id"],
                       index = None)
ts_loans.head()
# Out:
#             id
# issue_d
# 2007-07-01   4
# 2007-08-01   3
# 2007-09-01   2
# 2007-10-01   5
# 2007-11-01   3

# %%
# Let's check type of our index is as expected
ts_loans.index
# Out:
# DatetimeIndex(['2007-07-01', '2007-08-01', '2007-09-01', '2007-10-01',
#                '2007-11-01', '2007-12-01', '2008-01-01', '2008-02-01',
#                '2008-03-01', '2008-04-01',
#                ...
#                '2019-12-01', '2020-01-01', '2020-02-01', '2020-03-01',
#                '2020-04-01', '2020-05-01', '2020-06-01', '2020-07-01',
#                '2020-08-01', '2020-09-01'],
#               dtype='datetime64[ns]', name='issue_d', length=159, freq=None)

# %%
ts_loans.index.to_series().diff()[:5]
# Out:
# issue_d
# 2007-07-01       NaT
# 2007-08-01   31 days
# 2007-09-01   31 days
# 2007-10-01   30 days
# 2007-11-01   31 days
# Name: issue_d, dtype: timedelta64[ns]

# %%
# Resample to monthly frequency, using mean for aggregation
ts_loans_yearly = ts_loans.resample('Y').sum() # Alternatively, use mean()

ts_loans_yearly
# Out:
#                id
# issue_d
# 2007-12-31     20
# 2008-12-31     86
# 2009-12-31    184
# 2010-12-31    459
# 2011-12-31    787
# 2012-12-31   1720
# 2013-12-31   4492
# 2014-12-31   8227
# 2015-12-31  14386
# 2016-12-31  14710
# 2017-12-31  15251
# 2018-12-31  16881
# 2019-12-31  17854
# 2020-12-31   4943

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#Set the Seaborn style
sns.set(style="darkgrid")

# Create the plot
plt.figure(figsize=(14, 7))
sns.lineplot(x=ts_loans_yearly.index, y=ts_loans_yearly['id'])

# Adding titles and labels
plt.title('Time Series Plot')
plt.xlabel('Date')
plt.ylabel('Value')

# Show the plot
plt.show()

# %%
df_dropped['year'] = df_dropped['issue_d'].dt.year
df_dropped['month'] = df_dropped['issue_d'].dt.month
df_dropped['day'] = df_dropped['issue_d'].dt.day
df_dropped['week'] = df_dropped['issue_d'].dt.isocalendar().week

# %%
df_mapped_deduped.head(100)
# Out:
#            id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate
# 97   78229659    22400.0      22400.0          22400.0   60 months   12.99%
# 98   41152834    12000.0      12000.0          12000.0   36 months    7.89%
# 99   86593522    16800.0      16800.0          16800.0   36 months   11.49%
#
#     installment grade sub_grade                            emp_title  \
# 0        134.93     B        B5                              cashier
# 1        500.07     B        B2                                  ABM
# 2        162.49     B        B3                               driver
# 3        522.42     B        B4                                  NaN
# 4        322.79     C        C2                       Shipping Clerk
# 5        131.89     B        B5                                  CSR
# 6        246.01     C        C1                              CDC lll
# 7        697.86     D        D2                        Snr Scientist
# 8        295.21     B        B3                                  NaN
# 9        779.57     A        A4                           Pharmacist
# 10       850.17     B        B5                   BILLING SPECIALIST
# 11       324.23     B        B1                Aircraft Electrician
# 12       650.62     B        B3                              Analyst
# 13       760.72     C        C3                      Police Officer
# 14       380.54     A        A5                  Office Specialists
# 15       369.17     D        D2                       Lead Custodial
# 16       231.54     B        B3                         Poker dealer
# 17        75.42     A        A4                         Meat Manager
# 18       714.45     D        D4                                  NaN
# 19       452.41     C        C1                  Executive Assistant
# 20       597.91     C        C2                       Sr Tax Analyst
# 21       279.16     C        C3                    Senior Mountmaker
# 22       113.21     B        B1                            Paralegal
# 23       389.46     D        D5                 Quality Control Tech
# 24       734.57     D        D4                              Manager
# 25       677.52     B        B3               DIRECTOR OF OPERATIONS
# 26       573.28     E        E4                Senior Vice President
# 27       184.47     A        A3                        Senior Teller
# 28       514.86     C        C1                  Personal assistant.
# 29       282.41     D        D2      Orthopedic Clinic Front Office
# 30       276.02     E        E4                              courier
# 31       697.90     C        C4                   Production Manager
# 32       461.13     C        C2                    Underground miner
# 33       445.40     C        C1              VP Economic Development
# 34       480.43     B        B2                  Executive Assistant
# 35       491.53     D        D5                             engineer
# 36       106.15     A        A2                  Steward Health Care
# 37       156.66     A        A5            Customer services manager
# 38       465.27     C        C4                           supervisor
# 39       555.04     C        C4                       Vice-President
# 40       194.41     C        C2                       DRIVER TRAINER
# 41       523.78     E        E1              United States Air Force
# 42       556.37     D        D5                              Teacher
# 43       163.20     C        C2        Director,  Program Management
# 44       414.50     E        E3                             manager
# 45       942.73     A        A4                 Catastrophe Adjuster
# 46       403.12     C        C1                         Truck driver
# 47       276.06     C        C2                   Commercial Banking
# 48       769.99     A        A3                                  CFO
# 49       185.32     A        A2                         Truck driver
# 50       754.18     A        A4               HR Benefits Specialist
# 51       287.00     C        C2                           Supervisor
# 52       463.07     B        B3                              Teacher
# 53       253.70     A        A5                        Care Provider
# 54       389.93     C        C3                                  NaN
# 55       176.70     B        B1                 Del Rey Pool Plaster
# 56       304.59     A        A2                                  NaN
# 57       498.15     B        B3                     Claims Assistant
# 58       519.15     D        D3           Care Management Associate
# 59       385.60     D        D2                          Maintenance
# 60       294.61     B        B4                              MANAGER
# 61       196.24     C        C1               Kindergarten Assistant
# 62       372.00     A        A5                          Pastry Chef
# 63       569.63     C        C3               nursing supervisor, RN
# 64       192.34     C        C2                           Secretary
# 65       309.94     E        E3                                  Mvr
# 66       317.86     D        D4                 Accounting/Marketing
# 67       270.91     C        C2                   Resident Assistant
# 68       596.68     E        E4                            CTO Clerk
# 69       402.77     B        B5                 VP & General Counsel
# 70       606.41     B        B5                                  NaN
# 71       254.11     C        C2                                Sower
# 72       191.28     B        B2                                   RN
# 73       583.54     E        E1  Supervisory Foreign Affairs Officer
# 74       309.10     A        A2                     Practice Manager
# 75       424.74     C        C2                                 boss
# 76       351.62     C        C5                    ER Unit Secretary
# 77       544.17     D        D3                               deputy
# 78       707.48     C        C2                           Admissions
# 79       512.08     B        B1                               RN ICU
# 80       962.12     B        B1                   Account Specialist
# 81       496.19     C        C1                        Store Manager
# 82       227.49     B        B3            Special Education Teacher
# 83       217.83     C        C1                         truck driver
# 84       154.30     E        E1             Maintenance Coordinator
# 85      1039.03     F        F5                   Sr Program Officer
# 86       159.41     B        B5                   Unloader/processor
# 87       185.82     D        D2                      Banquet Captain
# 88        93.41     A        A3                               Driver
# 89       261.57     B        B4                      Acct. Specalist
# 90       365.72     C        C2                           Co-Manager
# 91       325.76     A        A5                   Executive Director
# 92       789.57     C        C1                        Sales Manager
# 93       646.74     C        C4                                Sales
# 94        71.08     B        B1                           Chauffeur
# 95       602.30     A        A1                                Owner
# 96       747.88     A        A3                   collision revision
# 97       509.56     C        C2                           Controller
# 98       375.43     A        A5                                Nurse
# 99       553.92     B        B5                             Manager
#
#    emp_length home_ownership  annual_inc verification_status   issue_d  \
# 0   10+ years       MORTGAGE     48000.0     Source Verified  Mar-2020
# 1     6 years           RENT     57000.0     Source Verified  Feb-2016
# 2   10+ years       MORTGAGE     55000.0        Not Verified  Jan-2015
# 3         NaN       MORTGAGE     43500.0        Not Verified  Jun-2018
# 4   10+ years       MORTGAGE     48000.0     Source Verified  Jan-2018
# 5   10+ years           RENT     46000.0            Verified  Nov-2015
# 6     6 years       MORTGAGE     33000.0        Not Verified  Jan-2014
# 7     2 years           RENT     99000.0        Not Verified  Mar-2016
# 8         NaN       MORTGAGE     30026.0            Verified  Mar-2020
# 9     4 years           RENT    129514.0        Not Verified  May-2019
# 10    6 years       MORTGAGE     95000.0            Verified  Jan-2018
# 11    7 years           RENT     62400.0     Source Verified  Jul-2019
# 12  10+ years           RENT     86000.0     Source Verified  May-2018
# 13  10+ years           RENT    120000.0     Source Verified  Oct-2019
# 14    6 years       MORTGAGE     46000.0        Not Verified  Oct-2019
# 15  10+ years       MORTGAGE     45000.0     Source Verified  Apr-2015
# 16    9 years           RENT     72000.0        Not Verified  Dec-2019
# 17    5 years       MORTGAGE     55000.0        Not Verified  Oct-2019
# 18        NaN       MORTGAGE    112000.0     Source Verified  Dec-2014
# 19    4 years       MORTGAGE     72000.0        Not Verified  Feb-2017
# 20    5 years           RENT     88000.0     Source Verified  Nov-2019
# 21    2 years       MORTGAGE     62000.0     Source Verified  Apr-2017
# 22     1 year           RENT     71000.0     Source Verified  Feb-2017
# 23    7 years            OWN     47000.0        Not Verified  Nov-2018
# 24    5 years       MORTGAGE     42000.0            Verified  Jun-2019
# 73    3 years       MORTGAGE    127000.0     Source Verified  Jun-2014
# 74  10+ years           RENT    120000.0        Not Verified  May-2017
# 75  10+ years       MORTGAGE     25000.0        Not Verified  Aug-2017
# 76  10+ years           RENT     50000.0            Verified  Apr-2018
# 77  10+ years       MORTGAGE     84000.0     Source Verified  Mar-2014
# 78    9 years       MORTGAGE     98000.0            Verified  Feb-2016
# 79  10+ years       MORTGAGE    164000.0        Not Verified  Oct-2017
# 80  10+ years       MORTGAGE    130000.0     Source Verified  Jul-2018
# 81    7 years       MORTGAGE     46000.0        Not Verified  Mar-2018
# 82    7 years           RENT     65000.0     Source Verified  Nov-2014
# 83    6 years       MORTGAGE     98000.0            Verified  Sep-2017
# 84  10+ years           RENT     60000.0     Source Verified  Apr-2017
# 85    2 years       MORTGAGE    101700.0            Verified  Feb-2014
# 86   < 1 year           RENT     41000.0            Verified  Sep-2017
# 87    3 years           RENT     60000.0        Not Verified  Apr-2019
# 88     1 year           RENT     55000.0        Not Verified  Sep-2019
# 89  10+ years       MORTGAGE     58000.0        Not Verified  Oct-2017
# 90    2 years           RENT     35900.0     Source Verified  Oct-2014
# 91  10+ years            OWN    152000.0        Not Verified  Aug-2017
# 92    6 years       MORTGAGE    140000.0            Verified  Sep-2017
# 93    7 years       MORTGAGE     70000.0     Source Verified  Dec-2015
# 94    7 years           RENT     30000.0     Source Verified  Sep-2018
# 95    6 years           RENT     60000.0        Not Verified  Jun-2016
# 96    9 years       MORTGAGE    100000.0            Verified  Sep-2013
# 97  10+ years       MORTGAGE    115000.0        Not Verified  May-2016
# 98    2 years           RENT     75000.0     Source Verified  Feb-2015
# 99    6 years           RENT    120000.0        Not Verified  Aug-2016
#
#            loan_status pymnt_plan  \
# 0              Current          n
# 1              Current          n
# 2           Fully Paid          n
# 3              Current          n
# 4           Fully Paid          n
# 5          Charged Off          n
# 6           Fully Paid          n
# 7           Fully Paid          n
# 8               Issued          n
# 9              Current          n
# 10             Current          n
# 11             Current          n
# 12         Charged Off          n
# 13             Current          n
# 14          Fully Paid          n
# 15             Current          n
# 16             Current          n
# 17          Fully Paid          n
# 18          Fully Paid          n
# 19          Fully Paid          n
# 20             Current          n
# 21          Fully Paid          n
# 22          Fully Paid          n
# 23         Charged Off          n
# 24  Late (31-120 days)          n
# 25         Charged Off          n
# 26          Fully Paid          n
# 27             Current          n
# 28             Current          n
# 29          Fully Paid          n
# 30          Fully Paid          n
# 31          Fully Paid          n
# 32             Current          n
# 33          Fully Paid          n
# 34          Fully Paid          n
# 35          Fully Paid          n
# 36          Fully Paid          n
# 37          Fully Paid          n
# 38          Fully Paid          n
# 39          Fully Paid          n
# 40          Fully Paid          n
# 41          Fully Paid          n
# 42             Current          n
# 43          Fully Paid          n
# 44         Charged Off          n
# 45             Current          n
# 46          Fully Paid          n
# 47             Current          n
# 48             Current          n
# 49             Current          n
# 50             Current          n
# 51             Current          n
# 52             Current          n
# 53             Current          n
# 54          Fully Paid          n
# 55          Fully Paid          n
# 56             Current          n
# 57          Fully Paid          n
# 58         Charged Off          n
# 59         Charged Off          n
# 60          Fully Paid          n
# 61          Fully Paid          n
# 62             Current          n
# 63             Current          n
# 64          Fully Paid          n
# 65         Charged Off          n
# 66             Current          n
# 67         Charged Off          n
# 68         Charged Off          n
# 69             Current          n
# 70          Fully Paid          n
# 71             Current          n
# 72          Fully Paid          n
# 73          Fully Paid          n
# 74             Current          n
# 75          Fully Paid          n
# 76             Current          n
# 77          Fully Paid          n
# 78          Fully Paid          n
# 79             Current          n
# 80             Current          n
# 81          Fully Paid          n
# 82          Fully Paid          n
# 83          Fully Paid          n
# 84             Current          n
# 85          Fully Paid          n
# 86             Current          n
# 87             Current          n
# 88             Current          n
# 89          Fully Paid          n
# 90          Fully Paid          n
# 91             Current          n
# 92             Current          n
# 93          Fully Paid          n
# 94          Fully Paid          n
# 95          Fully Paid          n
# 96          Fully Paid          n
# 97             Current          n
# 98          Fully Paid          n
# 99          Fully Paid          n
#
#                                                   url             purpose  \
# 0   https://lendingclub.com/browse/loanDetail.acti...    home_improvement
# 1   https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 2   https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 3   https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 4   https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 5   https://lendingclub.com/browse/loanDetail.acti...              moving
# 6   https://lendingclub.com/browse/loanDetail.acti...    home_improvement
# 7   https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 8   https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 9   https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 10  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 11  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 12  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 13  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 14  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 15  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 16  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 17  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 18  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 19  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 20  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 21  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 22  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 23  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 24  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 25  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 26  https://lendingclub.com/browse/loanDetail.acti...    home_improvement
# 27  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 28  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 29  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 30  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 31  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 32  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 33  https://lendingclub.com/browse/loanDetail.acti...    home_improvement
# 34  https://lendingclub.com/browse/loanDetail.acti...            vacation
# 35  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 36  https://lendingclub.com/browse/loanDetail.acti...    home_improvement
# 37  https://lendingclub.com/browse/loanDetail.acti...               other
# 38  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 39  https://lendingclub.com/browse/loanDetail.acti...    home_improvement
# 40  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 41  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 42  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 43  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 44  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 45  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 46  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 47  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 48  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 49  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 50  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 51  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 52  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 53  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 54  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 55  https://lendingclub.com/browse/loanDetail.acti...               other
# 56  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 57  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 58  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 59  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 60  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 61  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 62  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 63  https://lendingclub.com/browse/loanDetail.acti...                 car
# 64  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 65  https://lendingclub.com/browse/loanDetail.acti...               other
# 66  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 67  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 68  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 69  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 70  https://lendingclub.com/browse/loanDetail.acti...    home_improvement
# 71  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 72  https://lendingclub.com/browse/loanDetail.acti...             medical
# 73  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 74  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 75  https://lendingclub.com/browse/loanDetail.acti...    home_improvement
# 76  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 77  https://lendingclub.com/browse/loanDetail.acti...             medical
# 78  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 79  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 80  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 81  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 82  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 83  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 84  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 85  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 86  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 87  https://lendingclub.com/browse/loanDetail.acti...               other
# 88  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 89  https://lendingclub.com/browse/loanDetail.acti...            vacation
# 90  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 91  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 92  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 93  https://lendingclub.com/browse/loanDetail.acti...               other
# 94  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 95  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 96  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 97  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 98  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
#
# 82         Feb-2008           680.0            684.0             0.0
# 83         Apr-2006           680.0            684.0             1.0
# 84         Sep-2001           665.0            669.0             3.0
# 85         Sep-2003           695.0            699.0             0.0
# 86         Jul-2001           670.0            674.0             1.0
# 87         Sep-2009           705.0            709.0             0.0
# 88         Jan-2008           790.0            794.0             1.0
# 89         Sep-1996           690.0            694.0             2.0
# ...
# 34                    N            NO_HARDSHIP                4202.130
# 35                    N            NO_HARDSHIP               14044.480
# 36                    N            NO_HARDSHIP                 124.820
# 37                    N            NO_HARDSHIP                4040.300
# 38                    N            NO_HARDSHIP                7293.640
# 39                    N            NO_HARDSHIP               15880.190
# 40                    N            NO_HARDSHIP                4089.720
# 41                    N            NO_HARDSHIP                9021.970
# 42                    N            NO_HARDSHIP                 556.370
# 43                    N            NO_HARDSHIP                3795.600
# 44                    N            NO_HARDSHIP                 414.500
# 45                    N                 ACTIVE                   0.000
# 46                    N            NO_HARDSHIP                9079.830
# 47                    N            NO_HARDSHIP                 276.060
# 48                    N            NO_HARDSHIP                 769.990
# 49                    N            NO_HARDSHIP                 185.320
# 50                    N            NO_HARDSHIP                 754.180
# 51                    N            NO_HARDSHIP                 287.000
# 52                    N            NO_HARDSHIP                 463.070
# 53                    N            NO_HARDSHIP                 253.700
# 54                    N            NO_HARDSHIP                 389.590
# 55                    N            NO_HARDSHIP                 149.000
# 56                    N            NO_HARDSHIP                 304.590
# 57                    N            NO_HARDSHIP               12235.440
# 58                    Y              COMPLETED                 519.150
# 59                    N            NO_HARDSHIP                 385.600
# 60                    N            NO_HARDSHIP                 294.420
# 61                    N            NO_HARDSHIP                 195.820
# 62                    N            NO_HARDSHIP                 372.000
# 63                    N            NO_HARDSHIP                 569.630
# 64                    N            NO_HARDSHIP                3904.130
# 65                    Y            NO_HARDSHIP                 309.940
# 66                    N            NO_HARDSHIP                 317.860
# 67                    N            NO_HARDSHIP                 270.910
# 68                    N            NO_HARDSHIP                 596.680
# 69                    N            NO_HARDSHIP                 402.770
# 70                    N            NO_HARDSHIP                 606.170
# 71                    N               COMPLETE                   0.000
# 72                    N            NO_HARDSHIP                 946.900
# 73                    N            NO_HARDSHIP                7009.330
# 74                    N                 ACTIVE                   0.000
# 75                    N            NO_HARDSHIP                6308.690
# 76                    N            NO_HARDSHIP                   0.000
# 77                    N            NO_HARDSHIP                 544.130
# 78                    N            NO_HARDSHIP               14537.780
# 79                    N            NO_HARDSHIP                 512.080
# 80                    N            NO_HARDSHIP                 962.120
# 81                    N            NO_HARDSHIP               17440.046
# 82                    N            NO_HARDSHIP                 227.240
# 83                    N            NO_HARDSHIP                1279.800
# 84                    N                 ACTIVE                   0.000
# 85                    N            NO_HARDSHIP               17440.046
# 86                    N            NO_HARDSHIP                 159.410
# 87                    N                 ACTIVE                   0.000
# 88                    N            NO_HARDSHIP                  93.410
# 89                    N            NO_HARDSHIP                6523.480
# 90                    N            NO_HARDSHIP                 365.630
# 91                    N            NO_HARDSHIP                1293.600
# 92                    N            NO_HARDSHIP                 789.570
# 79         122265979                               rn icu             False
# 80         135456925                   account specialist             False
# 81         130102758                        store manager              True
# 82          35663855            special education teacher             False
# 83         117894170                         truck driver             False
# 84         104319549              maintenance coordinator             False
# 85          10638391                   sr program officer             False
# 86         119998371                   unloader/processor             False
# 87         150086341                      banquet captain             False
# 88         159101512                               driver             False
# 89         121784080                      acct. specalist             False
# 90          31747904                           co-manager              True
# 91         115435522                   executive director             False
# 92         118251329                        sales manager              True
# 93          66573985                                sales             False
# 94         139540982                            chauffeur             False
# 95          80868124                                owner             False
# 96           6905437                   collision revision             False
# 97          78229659                           controller             False
# 98          41152834                                nurse             False
# 99          86593522                              manager              True
#
#        Job Title    Category
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# 5            NaN         NaN
# 6            NaN         NaN
# 7            NaN         NaN
# 8            NaN         NaN
# 9            NaN         NaN
# 10           NaN         NaN
# 11           NaN         NaN
# 12           NaN         NaN
# 13           NaN         NaN
# 14           NaN         NaN
# 15           NaN         NaN
# 16           NaN         NaN
# 17           NaN         NaN
# 18           NaN         NaN
# 19           NaN         NaN
# 20           NaN         NaN
# 21           NaN         NaN
# 22           NaN         NaN
# 23           NaN         NaN
# 24       manager  Management
# 25           NaN         NaN
# 26           NaN         NaN
# 27           NaN         NaN
# 28           NaN         NaN
# 29           NaN         NaN
# 30           NaN         NaN
# 31           NaN         NaN
# 32           NaN         NaN
# 33           NaN         NaN
# 34           NaN         NaN
# 35           NaN         NaN
# 36           NaN         NaN
# 37           NaN         NaN
# 38    supervisor  Management
# 39           NaN         NaN
# 40           NaN         NaN
# 41           NaN         NaN
# 42       teacher   Education
# 43           NaN         NaN
# 44       manager  Management
# 45           NaN         NaN
# 46  truck driver   Logistics
# 47           NaN         NaN
# 48           NaN         NaN
# 49  truck driver   Logistics
# 50           NaN         NaN
# 51    supervisor  Management
# 52       teacher   Education
# 53           NaN         NaN
# 54           NaN         NaN
# 55           NaN         NaN
# 56           NaN         NaN
# 57           NaN         NaN
# 58           NaN         NaN
# 59           NaN         NaN
# 60       manager  Management
# 61           NaN         NaN
# 62           NaN         NaN
# 63           NaN         NaN
# 64           NaN         NaN
# 65           NaN         NaN
# 66           NaN         NaN
# 67           NaN         NaN
# 68           NaN         NaN
# 69           NaN         NaN
# 70           NaN         NaN
# 71           NaN         NaN
# 72           NaN         NaN
# 73           NaN         NaN
# 74           NaN         NaN
# 75           NaN         NaN
# 76           NaN         NaN
# 77           NaN         NaN
# 78           NaN         NaN
# 79           NaN         NaN
# 80           NaN         NaN
# 81           NaN         NaN
# 82           NaN         NaN
# 83  truck driver   Logistics
# 84           NaN         NaN
# 85           NaN         NaN
# 86           NaN         NaN
# 87           NaN         NaN
# 88           NaN         NaN
# 89           NaN         NaN
# 90           NaN         NaN
# 91           NaN         NaN
# 92           NaN         NaN
# 93         sales       Sales
# 94           NaN         NaN
# 95         owner   Executive
# 96           NaN         NaN
# 97    controller     Finance
# 98           NaN         NaN
# 99       manager  Management

# %%
df_mapped_deduped.to_csv(rf"data/2-intermediate/out_df2.csv"
                        , index = False)
